# %% [markdown]
# ---

# %%
library(sf)
# Out:
# Linking to GEOS 3.6.1, GDAL 2.1.3, proj.4 4.9.3

# %%
db <- st_read('/Users/dani/anaconda/envs/gds/lib/python3.5/site-packages/pysal/examples/columbus/columbus.shp')
# Out:
# Reading layer `columbus' from data source `/Users/dani/anaconda/envs/gds/lib/python3.5/site-packages/pysal/examples/columbus/columbus.shp' using driver `ESRI Shapefile'
# Simple feature collection with 49 features and 20 fields
# geometry type:  POLYGON
# dimension:      XY
# bbox:           xmin: 5.874907 ymin: 10.78863 xmax: 11.28742 ymax: 14.74245
# epsg (SRID):    NA
# proj4string:    NA

# %% [markdown]
# ---

# %%
library(feather)

# %%
feather::write_feather(
        data.frame(list(HOVAL=db$HOVAL, 
                INC=db$INC)),
        'db_test.feather')
test <- feather::read_feather('db_test.feather')

# %% [markdown]
# ---

# %%
plot(db$geometry)
# Out:
# plot without title

# %%
st_crs(db)
# Out:
# Coordinate Reference System: NA
