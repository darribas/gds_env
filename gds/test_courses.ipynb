# %% [markdown]
# # Test GDSL courses

# %% [markdown]
# ## Download

# %% [markdown]
# - [Web Mapping & Analysis](https://github.com/GDSL-UL/wma)

# %%
! wget https://github.com/GDSL-UL/wma/archive/refs/heads/main.zip \
    && unzip main.zip \
    && rm main.zip

# %% [markdown]
# - [Spatial Modelling for Data Scientists](https://github.com/GDSL-UL/san)

# %%
! wget https://github.com/GDSL-UL/san/archive/refs/heads/master.zip \
    && unzip master.zip \
    && rm master.zip

# %% [markdown]
# - [R for Population Science](https://github.com/fcorowe/r4ps)

# %%
! wget https://github.com/fcorowe/r4ps/archive/refs/heads/main.zip \
    && unzip main.zip \
    && rm main.zip

# %% [markdown]
# ## Test SMDS

# %%
! cd san-master \
    && quarto render
# Out:
# [ 1/13] index.qmd
# [ 2/13] 01-overview.qmd
#
#
# processing file: 01-overview.qmd
#
# output file: 01-overview.knit.md
#
#
#
# processing file: 01-overview.qmd
#
# output file: 01-overview.knit.md
#
# [ 3/13] 02-spatial_data.qmd
#
#
# processing file: 02-spatial_data.qmd
#
# output file: 02-spatial_data.knit.md
#
#
#
# processing file: 02-spatial_data.qmd
#
# output file: 02-spatial_data.knit.md
#
# [ 4/13] 03-data-wrangling.qmd
#
#
# processing file: 03-data-wrangling.qmd
#   |.                                                  |   2% (unnamed-chunk-1) System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
#
# output file: 03-data-wrangling.knit.md
#
#
#
# processing file: 03-data-wrangling.qmd
#   |.                                                  |   2% (unnamed-chunk-1) System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
#
# ...

# %% [markdown]
# ## Test WMA

# %%
! cd wma-main \
    && quarto render

# %% [markdown]
# ## Test R4PS

# %%
! cd r4ps-main \
    && quarto render
# Out:
# [ 1/13] index.qmd
# [ 2/13] intro.qmd
# [ 3/13] intro-population-science.qmd
# [ 4/13] geodemographics.qmd
#
#
# processing file: geodemographics.qmd
#
# output file: geodemographics.knit.md
#
#
#
# processing file: geodemographics.qmd
#
# output file: geodemographics.knit.md
#
# [ 5/13] sequence-analysis.qmd
#
#
# processing file: sequence-analysis.qmd
#   |...                                                |   6% (unnamed-chunk-2) System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
#
# output file: sequence-analysis.knit.md
#
#
#
# processing file: sequence-analysis.qmd
#   |...                                                |   6% (unnamed-chunk-2) System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
#
# output file: sequence-analysis.knit.md
#
# [ 6/13] network.qmd
#
#
# processing file: network.qmd
# ...
